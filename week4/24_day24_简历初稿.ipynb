# %% [markdown]
# # 🩺 第二十四天 · 简历初稿（作品 → 简历 → 面试故事）
#
# **今天目标（约 1.5 小时）**：把 D23 上线的评测作品，转化成一份可投递的**实习岗简历初稿** + 一个 **3 分钟面试故事**草稿。
#
# **为什么 D24 就写简历**：计划里 12 月中旬前要达到"可投递状态"，而 11 月投递季开始前，简历要迭代 2–3 版——初稿越早写，终稿越从容。
#
# > ⚠️ 老规矩：先 **Kernel → Restart Kernel**（本课无代码，重启可选）。

# %% [markdown]
# ## 第 1 步 · 先读简历方法论（5 分钟）
#
# ### 你的简历策略：医学生投"医学数据/评测岗"的三板斧
# 1. **顺序**：求职意向 → 技能 → 项目经历 → 教育背景 → 其他。你的护城河是"医学 + 评测能力"，不是学历背景，所以项目必须放最显眼处；
# 2. **证据链**：每一条经历都要能被 GitHub 或记录证明——你的优势恰好是"过程全开源"，简历里直接放仓库链接；
# 3. **诚实红线**：
#    - 不虚构任何分数、名次、奖项（Kaggle 名次没有就不写名次）；
#    - "AI 辅助完成"直接写明——2027 年的招聘方默认人人用 AI，他们要的是"能监督、验证、纠错 AI"的人，这恰好是你 D17–D23 每天在做的事；
#    - 12.5% 不稳定、数字错位等发现必须与你报告一致，面试会被追问细节。
#
# ### 三个变体（一鱼多吃）
# | 场景 | 改动 |
# |---|---|
# | 实习投递（Boss直聘/牛客） | 用下方**实习岗版**，突出技能+项目+可到岗时间 |
# | 挑战杯报名 | 同版改"项目经历"为"作品简介"，补一段"创新点"（异源评测设计、人工终审铁律、数字错位发现） |
# | 考研复试 | 教育背景与医学主线放前，项目作为"科研素养/工具能力"证据，弱化求职措辞 |

# %% [markdown]
# ## 第 2 步 · 简历初稿模板（实习岗版）
#
# > 把下方内容复制到 Word/WPS 排成 1 页，【】处全部替换成你的真实信息（不确定就留空，别编）。
#
# ---
#
# # 简历 · 医学 AI 数据/评测方向实习
#
# **基本信息**
# - 姓名：【填写】｜电话：【填写】｜邮箱：【填写】
# - 求职意向：医学数据 / 大模型评测 方向实习（2027.1–4，可全职 + 远程）
# - GitHub：github.com/j0ngp（学习与项目全开源）
#
# **技能**
# - Python：pandas / numpy、csv / json 数据处理、Jupyter Notebook，能独立完成医疗表格数据「读→洗→筛→分组→出结论」全流程
# - 大模型评测：提示词设计、双模型交叉验证、依据质量判定（查证式核验）、评分体系设计（正确性 6 + 依据质量 4，满分 10）
# - 医学专业：临床医学在读，熟悉诊断 / 药理 / 临床指南 / 医学伦理，能对 AI 医学输出做专业终审
# - 工具：Git / GitHub、Excel、DeepSeek / 通义千问等主流大模型
# - 英语：【填写 CET 成绩】｜其他证书：【填写】
#
# **项目经历**
# **医学大模型基础能力评测集 v2**（2026.8–9，独立完成）
# - 构建 48 题医学单选题评测集，覆盖诊断/用药/指南/伦理 4 维度，题目源自执医真题改编与指南原文检索，每题含标准答案与出处锚定
# - 设计「AI 起草 → 双模型交叉验证 → 医学专业人工终审」的答案键质控流水线：44/48 题双模型一致，4 题分歧经教材原文终审裁决
# - 完成对通义千问的正式评测（异源判分设计）：准确率 85.4%、平均分 8.54/10；发现「真实数字放错位置」类错误 3 例、同模型两次作答 12.5% 翻转
# - 撰写评测报告；48 题评分明细与逐题查证记录全部开源可追溯
#
# **Kaggle Titanic 入门赛**（2026.8）
# - 完成数据探索与首次提交，跑通 pandas「读→洗→筛→分组→出结论」实战流程
#
# **25 天学习全程开源**（2026.8–今）
# - GitHub 仓库按周归档（week1 Python 基础 → week2 文件/JSON/pandas → week3 数据实战 → week4 评测方法论），每周周报，提交历史即成长曲线
#
# **教育背景**
# - 昆明医科大学 · 临床医学（五年制）｜【入学年份】–2028.6（预计）｜GPA/排名：【填写】
# - 主修课程：内科学、外科学、诊断学、药理学、医学伦理学等
#
# **自我评价（3 句）**
# - 临床医学背景 + 自驱补齐编程，具备「看懂医学问题 + 验证 AI 输出对错」的复合能力；
# - 对 AI 输出保持怀疑，习惯用教材/指南原文做终审——项目中两次纠正 AI 误判，并把「人工终审」固化为工作铁律；
# - 2027.1.13 起可全职实习 6 周，开学后每周可保证 10–15h 远程，总时长可满 3 个月。

# %% [markdown]
# ## 第 3 步 · 作业 1：填空 + 自查（30 分钟）
#
# - [ ] 【】处信息全部填写（不确定就留空，不编造）
# - [ ] 每条经历都能在 GitHub 找到对应证据
# - [ ] 数字与《评测报告》一致（85.4%、8.54、12.5%、44/48）
# - [ ] 排版压缩到 1 页
# - [ ] 文件名建议：`简历_j0ngp_医学AI实习.md`（或 .docx）
#
# > 填完把简历贴回来，我帮你逐条挑毛病（今天我就是"挑刺的 HR"）。

# %% [markdown]
# ## 第 4 步 · 作业 2：3 分钟面试故事（30 分钟，STAR 法草稿）
#
# 面试必问题："讲讲你的评测集项目。" 用 STAR 法回答，写在这里：
#
# ```
# S 情境：想做医学问答评测集，但担心"AI 出题 + AI 判分"同源，错误会互相掩护。
# T 任务：建一套第三方能独立核验的评测集，并对一个模型完成正式评测。
# A 行动：
#   1. 48 题源自执医真题改编 + 指南原文检索，每题锚定出处；
#   2. 用第二个模型交叉验证答案键，分歧题由我按教材原文终审（期间两次纠正 AI 误判）；
#   3. 正式评测改用异源设计：被测模型与判分助手不同源，依据质量查证式初判 + 我人工终审。
# R 结果：通义千问准确率 85.4%、平均 8.54/10；发现 12.5% 作答不稳定和"真实数字放错位置"类错误；报告与全部数据开源。
# ```
#
# **你的草稿区**（用自己的话改写一遍，练习说出来）：
#
# （写在这里）

# %% [markdown]
# ## ✅ D24 完成标准（打钩）
#
# - [ ] 简历模板已填成自己的版本（1 页）
# - [ ] 自查清单全部通过
# - [ ] 面试故事草稿写完并口头演练 1 遍
# - [ ] 保存（**Cmd + S**）
#
# > 完成后喊我验收：简历贴回来我逐条挑刺；然后我帮你把今天成果提交到 week4，代理开着的话顺手推 GitHub。
