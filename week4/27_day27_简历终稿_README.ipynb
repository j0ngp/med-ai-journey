# %% [markdown]
# # 🩺 第二十七天 · 简历终稿 + GitHub README 润色
#
# **今天目标（约 1 小时）**：
# - **Part A**：简历升级 v2（应用 D24 必改项 + 补 CBLUE/三下乡）
# - **Part B**：GitHub README 重写（30 秒看懂你的仓库）——已由助手代写完成，你只需核对
# - 顺手准备 **D28 周报 4** 的素材（明天是 Week 4 收官日）
#
# > ⚠️ 老规矩：先 **Kernel → Restart Kernel**（无代码，重启可选）。

# %% [markdown]
# ## Part A · 简历 v2：D24 必改项核对（5 条全部落实）
#
# 助手已生成 `简历_v2_实习岗.md`（week4 文件夹），对照 D24 审阅意见逐条核对：
#
# - [ ] ✅ GPA「暂未知」→ 已改为「查教务系统后填写，暂缺则整行删除」
# - [ ] ✅ 【】方括号 → 已全部去掉（教育时间直接写 2023.9 – 2028.6）
# - [ ] ✅ 「25 天」天数 → 已删（改为「2026.8–今」，避免每周过期）
# - [ ] ✅ 证书全称 → 已注明「中国国际大学生创新大赛（原互联网+）」，**需你核对年份/全名**
# - [ ] ✅ 新增 CBLUE 75.7% 项目条目 + 机器学习技能（今天能写进简历，全靠 D26 学明白）
#
# **你的动作**：
# 1. 打开 `简历_v2_实习岗.md`，把内容贴进桌面 `简历.docx`（真实电话/邮箱只填 docx，不传 GitHub）；
# 2. 核对证书全称与年份；
# 3. 排版压缩到 1 页；
# 4. 面试故事更新：加入 CBLUE 75.7% 一句（30 秒项目 = 评测集 + CBLUE 双料）。

# %% [markdown]
# ## Part B · GitHub README 润色（已代写，你核对）
#
# README 已重写（仓库根目录），核心变化：
# - 顶部新增 **🎯 核心作品** 展示：48 题 / 双模型交叉验证 / 85.4% / 12.5% 不稳定 / 数字错位——30 秒抓住访客；
# - 新增 **💪 CBLUE 基线** 一栏（75.7%）；
# - 学习进度表更新：Week 1–3 ✅、Week 4 收尾中；
# - 里程碑补到 D26；目录结构补 week4。
#
# **你的动作**：打开 GitHub 仓库主页（开代理后）扫一眼排版，确认 30 秒内能看懂「你是谁、你干了什么」。

# %% [markdown]
# ## D28 周报 4 素材草稿（先备好）
#
# Week 4（D22–D27）干了什么：
# 1. D22 答案键审计：双模型交叉验证 48 题，44 一致 / 4 分歧 → 教材终审，导出 v2；
# 2. D23 异源评测：通义千问 48 题 → 85.4% / 8.54 分，发现 12.5% 不稳定 + 数字错位幻觉，报告上线；
# 3. D24 简历初稿 + 面试故事（STAR）；
# 4. D25–D26 CBLUE 启动 + TF-IDF/逻辑回归基线 75.7%，啃下 9 个 ML 概念；
# 5. 本周踩坑：① 代理时断时续（推 GitHub 卡住）；② 中文分词默认按空格 → char n-gram（36% vs 75.7%）；③ balanced 类权重在不均衡数据上崩盘（6.8%），去掉后正常。
#
# **难点/收获一句话**：本周最大的成长不是多了两个作品，而是立住了一条铁律——**AI 写的代码和结论，讲不明白就不算学会、不写进简历**。

# %% [markdown]
# ## ✅ D27 完成标准（打钩）
#
# - [ ] 简历 v2 已贴回桌面 docx 并排成 1 页
# - [ ] 证书全称/年份已核对
# - [ ] GitHub README 已核对（开代理后看主页）
# - [ ] 周报 4 素材已备好
# - [ ] 保存（**Cmd + S**）
#
# > 完成后喊我验收。**D28（明天）= Week 4 收官**：写周报 4 + 推 GitHub，Week 4 就正式结课。
